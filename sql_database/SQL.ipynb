# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Requirement already satisfied: ipython-sql in /home/flyiva-05/anaconda3/lib/python3.8/site-packages (0.4.0)',
#  'Requirement already satisfied: sqlalchemy>=0.6.7 in /home/flyiva-05/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.3.20)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in /home/flyiva-05/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.2.0)',
#  'Requirement already satisfied: ipython>=1.0 in /home/flyiva-05/anaconda3/lib/python3.8/site-packages (from ipython-sql) (7.19.0)',
#  'Requirement already satisfied: six in /home/flyiva-05/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.15.0)',
#  'Requirement already satisfied: sqlparse in /home/flyiva-05/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.4.1)',
#  'Requirement already satisfied: prettytable<1 in /home/flyiva-05/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.7.2)',
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///vbo.db

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
#Manuelly creating table

# %%
# %%sql
# CREATE TABLE new_table(firstname varchar(20),
#                        lastname varchar(20));
# Out:
#  * sqlite:///vbo.db
# Done.
# []

# %%
# %%sql
# INSERT INTO new_table values('Mustafa', 'Akdoğan');
# Out:
#  * sqlite:///vbo.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM new_table
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Mustafa', 'Akdoğan')]

# %%
# %%sql
# INSERT INTO new_table values('Ahmet', 'Akdoğan');
# Out:
#  * sqlite:///vbo.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM new_table
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Mustafa', 'Akdoğan'), ('Ahmet', 'Akdoğan')]

# %%
##SELECT

# %%
# %%sql
# SELECT * FROM Products LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
#all tables of database

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Suppliers',),
#  ('Shippers',),
#  ('Orders',),
#  ('OrderDetails',),
#  ('Employees',),
#  ('Customers',),
#  ('new_table',)]

# %%
# %%sql
# SELECT CustomerName,City,Country FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Alfreds Futterkiste', 'Berlin', 'Germany'),
#  ('Ana Trujillo Emparedados y helados', 'México D.F.', 'Mexico'),
#  ('Antonio Moreno Taquería', 'México D.F.', 'Mexico')]

# %%
# %%sql
# SELECT Price,Price*2 FROM Products LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(18, 36),
#  (19, 38),
#  (10, 20),
#  (22, 44),
#  (21, 42),
#  (25, 50),
#  (30, 60),
#  (40, 80),
#  (97, 194),
#  (31, 62)]

# %%
# %%sql
# SELECT Price AS original_price,Price*2 AS last_price FROM Products LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(18, 36),
#  (19, 38),
#  (10, 20),
#  (22, 44),
#  (21, 42),
#  (25, 50),
#  (30, 60),
#  (40, 80),
#  (97, 194),
#  (31, 62)]

# %%
# %%sql
# SELECT COUNT(*) AS count FROM Customers;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(91,)]

# %%
# %%sql
# SELECT * FROM Products ORDER BY Price LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(13, 'Konbu', 6, 8, '2 kg box', 6),
#  (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7),
#  (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14)]

# %%
# WHERE

# %%
# %%sql
# SELECT * FROM Customers WHERE Country='Sweden'
# Out:
#  * sqlite:///vbo.db
# Done.
# [(5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (24, 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')]

# %%
# %%sql
# SELECT * FROM Customers WHERE NOT City='Berlin' LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE PostalCode = 5021;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Customers WHERE PostalCode > 5021 LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
# ...

# %%
 # AND OR

# %%
# %%sql
# SELECT * FROM Customers WHERE Country="UK" AND City='London'
# Out:
#  * sqlite:///vbo.db
# Done.
# [(4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')]

# %%
# %%sql
# SELECT * FROM Customers WHERE Country="UK" OR Country='USA'
# Out:
#  * sqlite:///vbo.db
# Done.
# [(4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (38, 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE Country="USA" AND (City='Eugene' OR City='Elgin');
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')]

# %%
# %%sql
# SELECT * FROM Customers WHERE Country="USA" AND PostalCode=97403 AND (City='Eugene' OR City='Elgin');
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')]

# %%
# IN / NOT IN

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerID in (1,3,5,7);
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')]

# %%
# %%sql
# SELECT * FROM Customers WHERE Country="USA" AND City in ('Eugene', 'Elgin');
# Out:
#  * sqlite:///vbo.db
# Done.
# [(32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')]

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerID NOT in (1,3,5,7) LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (12, 'Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE Country="USA" AND City NOT IN ('Eugene', 'Elgin') LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA'),
#  (71, 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA'),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA'),
#  (77, 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA'),
#  (78, 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA'),
# ...

# %%
# LIKE
# '_r%' ikinci sırasında r olan değerler
# 'a%% ' a ile başlayıp en az 3 karakterden oluşan değerler
# 'a%o' a ile başlayıp o ile biten değerler

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE '%or%' LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (40, "La corne d'abondance", 'Daniel Tonini', "67, avenue de l'Europe", 'Versailles', '78000', 'France'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '4179', 'Germany'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK'),
# ...

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE '%a' LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (30, 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero, 33', 'Sevilla', '41101', 'Spain'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
#  (88, 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil'),
#  (90, 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')]

# %%
# %%sql
# SELECT * FROM Customers WHERE CustomerName LIKE 'A%' AND Country LIKE '%o' LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# BETWEEN

# %%
# %%sql
# SELECT * FROM Products WHERE Price BETWEEN 10 AND 20 LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14),
#  (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14),
#  (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18),
#  (36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18)]

# %%
# %%sql
# SELECT * FROM Products WHERE Price NOT BETWEEN 10 AND 20 LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21),
#  (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38),
#  (13, 'Konbu', 6, 8, '2 kg box', 6)]

# %%
# %%sql
# SELECT * FROM Products WHERE (Price BETWEEN 10 AND 20) AND CategoryID NOT IN (1,2,3) LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(36, 'Inlagd Sill', 17, 8, '24 - 250 g jars', 19),
#  (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (54, 'Tourtière', 25, 6, '16 pies', 16),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (73, 'Röd Kaviar', 17, 8, '24 - 150 g jars', 15),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10)]

# %%
# %%sql
# SELECT ProductName FROM Products WHERE (Price BETWEEN 10 AND 20) AND CategoryID NOT IN (1,2,3) LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Inlagd Sill',),
#  ('Singaporean Hokkien Fried Mee',),
#  ('Spegesild',),
#  ('Tourtière',),
#  ('Escargots de Bourgogne',),
#  ('Röd Kaviar',),
#  ('Longlife Tofu',)]

# %%
# %%sql
# SELECT * FROM Products WHERE ProductName BETWEEN 'Carnarno Tigers' AND 'Mozzarella di Govanni' LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31),
#  (13, 'Konbu', 6, 8, '2 kg box', 6),
#  (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 43),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62)]

# %%
# Aggregation

# %%
# %%sql
# SELECT * FROM Products LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31)]

# %%
# %%sql
# SELECT MIN(Price) FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6,)]

# %%
# %%sql
# SELECT MIN(Price) AS min_price, MAX(Price) AS max_price FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(6, 435)]

# %%
# %%sql
# SELECT AVG(Price) AS avarage_price FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(39.15584415584416,)]

# %%
# %%sql
# SELECT SUM(Price) AS avarage_price FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3015,)]

# %%
# %%sql
# SELECT COUNT(Price) AS count, MIN(Price) AS min_price, MAX(Price) AS max_price, AVG(Price) AS avarage_price, SUM(Price) AS all_price FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(77, 6, 435, 39.15584415584416, 3015)]

# %%
# GROUP BY, AGGREGATİON

# %%
# %%sql
# SELECT COUNT(CustomerID) AS customer_count, Country FROM Customers GROUP BY Country ORDER BY customer_count DESC;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
# %%sql
# SELECT AVG(Price) AS avarage_price, CategoryID FROM Products GROUP BY CategoryID;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(42.75, 1),
#  (28.25, 2),
#  (33.76923076923077, 3),
#  (74.9, 4),
#  (23.571428571428573, 5),
#  (55.166666666666664, 6),
#  (32.2, 7),
#  (26.5, 8)]

# %%
# JOIN

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Suppliers',),
#  ('Shippers',),
#  ('Orders',),
#  ('OrderDetails',),
#  ('Employees',),
#  ('Customers',),
#  ('new_table',)]

# %%
# %%sql
# SELECT * FROM Categories LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads')]

# %%
# %%sql
# SELECT * FROM Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10)]

# %%
# left join

# %%
# %%sql
# SELECT * FROM Products LEFT OUTER JOIN Categories ON Products.CategoryID = Categories.CategoryID LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings')]

# %%
# %%sql
# SELECT Products.ProductName, CA.CategoryID, CA.CategoryName FROM Products LEFT OUTER JOIN Categories AS CA ON Products.CategoryID = CA.CategoryID LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Chais', 1, 'Beverages'),
#  ('Chang', 1, 'Beverages'),
#  ('Aniseed Syrup', 2, 'Condiments'),
#  ("Chef Anton's Cajun Seasoning", 2, 'Condiments'),
#  ("Chef Anton's Gumbo Mix", 2, 'Condiments')]

# %%
 # INNER JOIN

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# SELECT * FROM Orders LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(10248, 90, 5, '4.07.1996', 3),
#  (10249, 81, 6, '5.07.1996', 1),
#  (10250, 34, 4, '8.07.1996', 2)]

# %%
# %%sql
# SELECT Orders.OrderID, Customers.CustomerName FROM Orders INNER JOIN Customers ON Customers.CustomerID = Orders.CustomerID LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(10248, 'Wilman Kala'),
#  (10249, 'Tradição Hipermercados'),
#  (10250, 'Hanari Carnes'),
#  (10251, 'Victuailles en stock'),
#  (10252, 'Suprêmes délices')]

# %%
# %%sql
# SELECT COUNT(*) FROM Orders INNER JOIN Customers ON Customers.CustomerID = Orders.CustomerID LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(196,)]

# %%
# SQL AND PANDAS DATAFRAME OPERATIONS

# %%
import pandas as pd

# %%
# %%sql
# SELECT COUNT(CustomerID) AS count, Country FROM Customers GROUP BY Country ORDER BY count DESC;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
# PANDA DATAFRAME

# %%
df = %sql SELECT COUNT(CustomerID) AS count, Country FROM Customers GROUP BY Country ORDER BY count DESC;
# Out:
#  * sqlite:///vbo.db
# Done.

# %%
df
# Out:
# [(13, 'USA'),
#  (11, 'Germany'),
#  (11, 'France'),
#  (9, 'Brazil'),
#  (7, 'UK'),
#  (5, 'Spain'),
#  (5, 'Mexico'),
#  (4, 'Venezuela'),
#  (3, 'Italy'),
#  (3, 'Canada'),
#  (3, 'Argentina'),
#  (2, 'Switzerland'),
#  (2, 'Sweden'),
#  (2, 'Portugal'),
#  (2, 'Finland'),
#  (2, 'Denmark'),
#  (2, 'Belgium'),
#  (2, 'Austria'),
#  (1, 'Poland'),
#  (1, 'Norway'),
#  (1, 'Ireland')]

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'ResultSet' object has no attribute 'head'

# %%
type(df)
# Out:
# sql.run.ResultSet

# %%
dff = pd.DataFrame(df, columns=["count", "Countries"])

# %%
dff
# Out:
#     count    Countries
# 0      13          USA
# 1      11      Germany
# 2      11       France
# 3       9       Brazil
# 4       7           UK
# 5       5        Spain
# 6       5       Mexico
# 7       4    Venezuela
# 8       3        Italy
# 9       3       Canada
# 10      3    Argentina
# 11      2  Switzerland
# 12      2       Sweden
# 13      2     Portugal
# 14      2      Finland
# 15      2      Denmark
# 16      2      Belgium
# 17      2      Austria
# 18      1       Poland
# 19      1       Norway
# 20      1      Ireland

# %%
dff.head()
# Out:
#    count Countries
# 0     13       USA
# 1     11   Germany
# 2     11    France
# 3      9    Brazil
# 4      7        UK

# %%
dff.plot.barh(x = "Countries", y="count")
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
#sqlite3

# %%
import sqlite3

# %%
conn = sqlite3.connect('vbo.db')

# %%
# ?conn

# %%
c = conn.cursor()

# %%
# ?c

# %%
# ?pd.read_sql

# %%
#read sql

# %%
ab = pd.read_sql("SELECT COUNT(CustomerID) as count, Country FROM Customers GROUP BY Country ORDER BY count DESC;", conn)

# %%
type(ab)
# Out:
# pandas.core.frame.DataFrame

# %%
# conn.close()

# %%
c.execute("SELECT CustomerName FROM Customers LIMIT 5;")

# %%
c.fetchone()
# Out:
# ('Alfreds Futterkiste',)

# %%
c.fetchall()
# Out:
# [('Ana Trujillo Emparedados y helados',),
#  ('Antonio Moreno Taquería',),
#  ('Around the Horn',),
#  ('Berglunds snabbköp',)]

# %%
for row in c.execute("SELECT CustomerName FROM Customers LIMIT 5;"):
    print(row)
# Out:
# ('Alfreds Futterkiste',)
# ('Ana Trujillo Emparedados y helados',)
# ('Antonio Moreno Taquería',)
# ('Around the Horn',)
# ('Berglunds snabbköp',)

# %%
# HOMEWORKS

# %%
# Order tablosunda kaç müşteri olduğunu bulunuz

# %%
# %%sql
# SELECT COUNT(CustomerID) FROM Orders;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(196,)]

# %%
# Order tablosunda kaç tane eşsiz müşteri olduğunu blunuz

# %%
# %%sql
# SELECT COUNT(DISTINCT CustomerID) FROM Orders;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(74,)]

# %%
# Customer tablosunda hangi ülkeden kaçar tane müşteri olduğunu bulunuz

# %%
# %%sql
# SELECT COUNT(CustomerID), Country AS count from Customers GROUP BY Country ORDER BY count;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
# Müşterilerin ülkesi Brazil yada USA olanlarını blunuz

# %%
# %%sql
# SELECT * FROM Customers WHERE Country IN ('USA', 'Brazil');
# Out:
#  * sqlite:///vbo.db
# Done.
# [(15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (34, 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
# ...

# %%
# Önce ülkeye sonra şehre göre group by işlemiyapıp bu kırılımda müşteri sayısını bulunuz

# %%
# %%sql
# SELECT COUNT(CustomerID), Country, City FROM Customers GROUP BY Country, City;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Argentina', 'Buenos Aires'),
#  (1, 'Austria', 'Graz'),
#  (1, 'Austria', 'Salzburg'),
#  (1, 'Belgium', 'Bruxelles'),
#  (1, 'Belgium', 'Charleroi'),
#  (1, 'Brazil', 'Campinas'),
#  (1, 'Brazil', 'Resende'),
#  (3, 'Brazil', 'Rio de Janeiro'),
#  (4, 'Brazil', 'São Paulo'),
#  (1, 'Canada', 'Montréal'),
#  (1, 'Canada', 'Tsawassen'),
#  (1, 'Canada', 'Vancouver'),
#  (1, 'Denmark', 'København'),
#  (1, 'Denmark', 'Århus'),
#  (1, 'Finland', 'Helsinki'),
#  (1, 'Finland', 'Oulu'),
#  (1, 'France', 'Lille'),
#  (1, 'France', 'Lyon'),
#  (1, 'France', 'Marseille'),
#  (2, 'France', 'Nantes'),
#  (2, 'France', 'Paris'),
#  (1, 'France', 'Reims'),
#  (1, 'France', 'Strasbourg'),
#  (1, 'France', 'Toulouse'),
#  (1, 'France', 'Versailles'),
#  (1, 'Germany', 'Aachen'),
#  (1, 'Germany', 'Berlin'),
#  (1, 'Germany', 'Brandenburg'),
#  (1, 'Germany', 'Cunewalde'),
#  (1, 'Germany', 'Frankfurt a.M.'),
#  (1, 'Germany', 'Köln'),
# ...

# %%
# Müşterileri adreslerinin herhangi bi yerinde da ifadesi geçen tüm adresleri bulunuz

# %%
# %%sql
# SELECT CustomerName, Address FROM Customers WHERE Address LIKE '%da%';
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Ana Trujillo Emparedados y helados', 'Avda. de la Constitución 2222'),
#  ('Centro comercial Moctezuma', 'Sierras de Granada 9993'),
#  ('Comércio Mineiro', 'Av. dos Lusíadas, 23'),
#  ('Furia Bacalhau e Frutos do Mar', 'Jardim das rosas n. 32'),
#  ('Océano Atlántico Ltda.', 'Ing. Gustavo Moncada 8585 Piso 20-A'),
#  ('Princesa Isabel Vinhoss', 'Estrada da saúde n. 58'),
#  ('Que Delícia', 'Rua da Panificadora, 12'),
#  ('Queen Cozinha', 'Alameda dos Canàrios, 891'),
#  ('Reggiani Caseifici', 'Strada Provinciale 124'),
#  ('Tortuga Restaurante', 'Avda. Azteca 123'),
#  ("Trail's Head Gourmet Provisioners", '722 DaVinci Blvd.')]

# %%
# Germany-Berlinde yaşayan müşterilerin ismi

# %%
# %%sql
# SELECT CustomerName FROM Customers WHERE Country = 'Germany' AND City='Berlin';
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Alfreds Futterkiste',)]

# %%
# Canada da yaşayıp isimlerinde in ifadesi geçen müşterileri bulunuz

# %%
# %%sql
# SELECT * FROM Customers WHERE Country='Canada' AND CustomerName LIKE '%in%'
# Out:
#  * sqlite:///vbo.db
# Done.
# [(42, 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')]

# %%
# Fiyatı 40 ile 90 arasında olan ürünlerin isimleri ve fiyatları nelerdir

# %%
# %%sql
# SELECT Price, ProductName FROM Products WHERE Price BETWEEN 40 AND 90
# Out:
#  * sqlite:///vbo.db
# Done.
# [(40, 'Northwoods Cranberry Sauce'),
#  (43, 'Genen Shouyu'),
#  (62, 'Carnarvon Tigers'),
#  (43, 'Teatime Chocolate Biscuits'),
#  (81, "Sir Rodney's Marmalade"),
#  (43, 'Guaraná Fantástica'),
#  (43, 'Schoggi Schokolade'),
#  (45, 'Rössle Sauerkraut'),
#  (43, 'Geitost'),
#  (43, 'Boston Crab Meat'),
#  (46, 'Ipoh Coffee'),
#  (43, 'Røgede sild'),
#  (43, 'Zaanse koeken'),
#  (53, 'Manjimup Dried Apples'),
#  (43, 'Ravioli Angelo'),
#  (55, 'Raclette Courdavault'),
#  (43, "Sirop d'érable"),
#  (49, 'Tarte au sucre'),
#  (43, 'Vegie-spread'),
#  (43, 'Louisiana Fiery Hot Pepper Sauce'),
#  (45, 'Scottish Longbreads')]

# %%
# Fiyatı 30 dan büyük olan ürünlerin isimlerini, fiyatlarını ve fiyatlarının karesini bulunuz ve tüm değişkenleri aşağıdaki gibi isimlendirin

# %%
# %%sql
# SELECT ProductName AS product_name, Price AS product_price, Price*Price AS product_price_square FROM Products WHERE Price > 30;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Northwoods Cranberry Sauce', 40, 1600),
#  ('Mishi Kobe Niku', 97, 9409),
#  ('Ikura', 31, 961),
#  ('Queso Manchego La Pastora', 38, 1444),
#  ('Genen Shouyu', 43, 1849),
#  ('Alice Mutton', 39, 1521),
#  ('Carnarvon Tigers', 62, 3844),
#  ('Teatime Chocolate Biscuits', 43, 1849),
#  ("Sir Rodney's Marmalade", 81, 6561),
#  ('Guaraná Fantástica', 43, 1849),
#  ('Gumbär Gummibärchen', 31, 961),
#  ('Schoggi Schokolade', 43, 1849),
#  ('Rössle Sauerkraut', 45, 2025),
#  ('Thüringer Rostbratwurst', 123, 15129),
#  ('Gorgonzola Telino', 435, 189225),
#  ('Mascarpone Fabioli', 32, 1024),
#  ('Geitost', 43, 1849),
#  ('Côte de Blaye', 263, 69169),
#  ('Boston Crab Meat', 43, 1849),
#  ('Ipoh Coffee', 46, 2116),
#  ('Røgede sild', 43, 1849),
#  ('Zaanse koeken', 43, 1849),
#  ('Manjimup Dried Apples', 53, 2809),
#  ('Perth Pasties', 32, 1024),
#  ('Gnocchi di nonna Alice', 38, 1444),
#  ('Ravioli Angelo', 43, 1849),
#  ('Raclette Courdavault', 55, 3025),
# ...

# %%
# Products tablosundaki category_id lerin isimleri nelerdir?

# %%
# %%sql
# SELECT * FROM Products LEFT JOIN Categories ON Products.CategoryID = Categories.CategoryID;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30, 7, 'Produce', 'Dried fruit and bean curd'),
# ...

# %% [markdown]
# ### beverages ürün kategorisindeki ürünlerin fiyat ortalaması nedir

# %%
# %%sql
# SELECT AVG(Price) FROM Products LEFT JOIN Categories ON Products.CategoryID = Categories.CategoryID WHERE CategoryName = 'Beverages'
# Out:
#  * sqlite:///vbo.db
# Done.
# [(42.75,)]

# %% [markdown]
# ### USA de yaşayan müşterilerin kazandırdığı toplam kazanç

# %%
    # %%sql 
    SELECT SUM(p.Price) 
    FROM Orders o 
    LEFT JOIN OrderDetails od on o.OrderID = od.OrderID 
    LEFT JOIN Products p on od.ProductID = p.ProductID 
    LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID where cu.Country = 'USA';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3762,)]

# %%
    # %%sql 
    SELECT SUM(p.Price) 
    FROM Orders o 
    LEFT JOIN OrderDetails od on o.OrderID = od.OrderID 
    LEFT JOIN Products p on od.ProductID = p.ProductID 
    LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID where cu.Country = 'USA';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3762,)]

# %% [markdown]
# ### product tablosundaki category i lerin isimlerini bulunuz ve sorna kategory başına ortalam ürün fiyatlarını gösteriniz

# %%
# %%sql
# SELECT AVG(p.Price), CategoryName FROM Products AS p LEFT JOIN Categories AS c ON p.CategoryID = c.CategoryID GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(42.75, 'Beverages'),
#  (28.25, 'Condiments'),
#  (33.76923076923077, 'Confections'),
#  (74.9, 'Dairy Products'),
#  (23.571428571428573, 'Grains/Cereals'),
#  (55.166666666666664, 'Meat/Poultry'),
#  (32.2, 'Produce'),
#  (26.5, 'Seafood')]

# %% [markdown]
# ### Çalışanları isimleri ile birlikte yapdıkları toplan satışlara göre sıralayınız

# %%
    # %%sql
    SELECT em.FirstName, SUM(p.Price) toplam_satis 
    FROM Orders o 
    LEFT JOIN OrderDetails od on o.OrderID = od.OrderID 
    LEFT JOIN Products p on od.ProductID = p.ProductID 
    LEFT JOIN Employees em on o.EmployeeID = em.EmployeeID 
    GROUP BY o.EmployeeID 
    ORDER BY toplam_satis DESC;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Margaret', 5515),
#  ('Nancy', 4353),
#  ('Janet', 3048),
#  ('Michael', 2981),
#  ('Laura', 2380),
#  ('Robert', 1852),
#  ('Andrew', 1550),
#  ('Steven', 1408),
#  ('Anne', 520)]

# %% [markdown]
# ### Almayada verilen siparişlerin kategorilerine göre ortalama fiyatları nelerdir?

# %%
    # %%sql
    SELECT ca.CategoryName, AVG(p.Price) 
    FROM Orders o 
    LEFT JOIN OrderDetails od on o.OrderID = od.OrderID 
    LEFT JOIN Products p on od.ProductID = p.ProductID 
    LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID 
    LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID 
    WHERE cu.Country = 'Germany' GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Beverages', 20.5),
#  ('Condiments', 34.0),
#  ('Confections', 40.0),
#  ('Dairy Products', 151.64705882352942),
#  ('Grains/Cereals', 22.142857142857142),
#  ('Meat/Poultry', 30.2),
#  ('Produce', 30.75),
#  ('Seafood', 27.09090909090909)]

# %% [markdown]
# ### Almanyada yada USA den verilen siparişlerinkategorilerine göre ortalama fiyatları nelerdir?

# %%
    # %%sql
    SELECT ca.CategoryName, AVG(p.Price) 
    FROM Orders o 
    LEFT JOIN OrderDetails od on o.OrderID = od.OrderID 
    LEFT JOIN Products p on od.ProductID = p.ProductID 
    LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID 
    LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID 
    WHERE cu.Country = 'Germany' OR cu.Country = 'USA' GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Beverages', 29.88888888888889),
#  ('Condiments', 34.72727272727273),
#  ('Confections', 39.92307692307692),
#  ('Dairy Products', 131.75862068965517),
#  ('Grains/Cereals', 29.846153846153847),
#  ('Meat/Poultry', 46.75),
#  ('Produce', 28.625),
#  ('Seafood', 25.6)]

# %% [markdown]
# ### Haziran Temmuz Ağustos aylarında verilen siparişlerin ortalama fiyatı nedir?

# %%
    # %%sql
    SELECT AVG(Products.Price) 
    FROM Products 
    LEFT JOIN OrderDetails on OrderDetails.ProductID = products.ProductID 
    LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID 
    WHERE OrderDate like '%07%' or OrderDate like '%08%' or OrderDate like '%09%';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(39.71891891891892,)]

# %% [markdown]
# ### Müşterilerin 1997 yılına ait siparişlerinin maksimum miktarlarını bulup müşterilerin isimleri ile birlikte büyükten küçüğe sıralayınız.

# %%
    # %%sql
    SELECT CustomerName, MAX(Price) maks 
    FROM Products 
    LEFT JOIN OrderDetails on Products.ProductID = OrderDetails.ProductID 
    LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID 
    LEFT JOIN Customers on Customers.CustomerID = Orders.CustomerID 
    WHERE OrderDate like '%1997%' 
    GROUP BY CustomerName ORDER BY maks DESC;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Gourmet Lanchonetes', 435),
#  ('Simons bistro', 263),
#  ('Mère Paillarde', 263),
#  ('Save-a-lot Markets', 123),
#  ('Eastern Connection', 123),
#  ('Wellington Importadora', 97),
#  ('Ernst Handel', 55),
#  ('Bottom-Dollar Marketse', 55),
#  ("La maison d'Asie", 49),
#  ('Folies gourmandes', 49),
#  ('Reggiani Caseifici', 45),
#  ('Queen Cozinha', 45),
#  ('Wartian Herkku', 43),
#  ('Toms Spezialitäten', 43),
#  ('Rattlesnake Canyon Grocery', 43),
#  ('Que Delícia', 43),
#  ('QUICK-Stop', 43),
#  ('Old World Delicatessen', 43),
#  ('Hungry Owl All-Night Grocers', 43),
#  ('Hungry Coyote Import Store', 43),
#  ('Familia Arquibaldo', 43),
#  ('Princesa Isabel Vinhoss', 38),
#  ('Galería del gastrónomo', 38),
#  ('Blondel père et fils', 38),
#  ('Richter Supermarkt', 36),
#  ('Ottilies Käseladen', 36),
#  ('Consolidated Holdings', 34),
#  ('Split Rail Beer & Ale', 31),
#  ('Magazzini Alimentari Riuniti', 31),
#  ('Franchi S.p.A.', 31),
# ...

# %% [markdown]
# ### Sipariş yılı 1997 olan siparişleri alan çalışanları sipariş alma sayılarına göre sıralayınız.

# %%
    # %%sql
    SELECT COUNT(*) n, em.FirstName 
    FROM Orders 
    LEFT JOIN Employees em on Orders.EmployeeID = em.EmployeeID 
    WHERE OrderDate like '%1997%' 
    GROUP BY em.FirstName 
    ORDER by n DESC;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(13, 'Janet'),
#  (9, 'Margaret'),
#  (8, 'Laura'),
#  (4, 'Andrew'),
#  (3, 'Robert'),
#  (3, 'Nancy'),
#  (3, 'Michael'),
#  (1, 'Anne')]
